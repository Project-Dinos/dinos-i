# %%
import pickle
posterior_list = []


with open('slacs_slit_const_processed.pkl', 'rb') as pickle_file:
    content = pickle.load(pickle_file)
    posterior_list.extend(content)  
    
with open('sl2s_slit_const_processed.pkl', 'rb') as pickle_file:
    content = pickle.load(pickle_file)
    posterior_list.extend(content)  
len(posterior_list)
# Out:
# 49

# %%
file = open('combined_slit_const_processed.pkl', 'wb')
pickle.dump(posterior_list, file)
file.close()

# %%
with open('combined_slit_const_processed.pkl', 'rb') as pickle_file:
    content = pickle.load(pickle_file)
    
content
# Out:
# [{'z_lens': 0.44,
#   'z_source': 1.192,
#   'likelihood_type': 'IFUKinCov',
#   'sigma_v_measurement': array([227.7464496]),
#   'anisotropy_model': 'const',
#   'j_model': array([3.18732293e-07]),
#   'error_cov_measurement': array([[741.39258525]]),
#   'error_cov_j_sqrt': array(2.62518075e-08),
#   'ani_param_array': array([-0.49      , -0.24166667,  0.00666667,  0.255     ,  0.50333333,
#           0.75166667,  1.        ]),
#   'ani_scaling_array_list': [[0.8975091334161179,
#     0.9309015423206368,
#     0.9773982026861925,
#     1.0443322271841275,
#     1.1292083703099283,
#     1.2600143809852131,
#     1.5808128027055905]],
#   'name': 'SDSSJ0008-0004'},
#  {'z_lens': 0.227,
#   'z_source': 0.931,
#   'likelihood_type': 'IFUKinCov',
#   'sigma_v_measurement': array([215.76101556]),
#   'anisotropy_model': 'const',
#   'j_model': array([5.05533266e-07]),
#   'error_cov_measurement': array([[220.15527211]]),
#   'error_cov_j_sqrt': array(5.91269425e-09),
# ...
