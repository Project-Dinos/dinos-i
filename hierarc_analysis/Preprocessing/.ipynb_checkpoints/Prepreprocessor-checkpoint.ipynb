# %%
import pandas as pd
import fitsio
import numpy as np

# %%
df = pd.read_csv('../v9_Sluse/old_params/slacs_all_params.csv')
vdisp = fitsio.read('../v0/vdisp_slacs_asb.fits')

# %%
gamma_sys_dict = {}

sys_error_df = pd.read_csv('../v9_Sluse/DINOS_Lenses_with_systematic_v2.csv')
for index, row in sys_error_df.iterrows():
    gamma_sys_dict[row['Lens Name']] = row['gamma_systematic']

# %%
z_lens_dict = {}
z_source_dict = {}
v_disp_dict = {}
v_disp_err_dict = {}

for index, row in df.iterrows():
   # print(row['name'], row['z_lens'], row['z_source'])
    z_lens_dict[row['name']] = row['z_lens']
    z_source_dict[row['name']] = row['z_source']
    
for i in vdisp:
    v_disp_dict[i[-1]] = i[-3]
    v_disp_err_dict[i[-1]] = i[-2]

# %%
mass_df = pd.read_csv('/home/s1/chinyi/80bdata/dinos/final_gold_analysis/2_data_tables/tables/SLACS_Gold_mass_params.csv')
light_df = pd.read_csv('/home/s1/chinyi/80bdata/dinos/final_gold_analysis/2_data_tables/tables/SLACS_Gold_light_params.csv')
result = pd.merge(mass_df, light_df,left_on="Lens Name",right_on="lens_name")

# %%
#result_cut = result[['name','z_lens','z_source','sigma_v','sigma_v_error',
#        'theta_E','theta_E_error','gamma','gamma_error','r_eff','r_eff_error','light_model',
#        'r_sersic_1','n_sersic_1','amp_sersic_1','r_sersic_2','n_sersic_2','amp_sersic_2'] ]

# %%
result['name'] = result['Lens Name']
result['theta_E'] = result['R_Ein']
result['theta_E_error'] = 0.5*(result['R_Ein E1'] + result['R_Ein E2'])
result['gamma'] = result['γ']
result['gamma_error_uncorr'] = 0.5*(result['γ E1'] + result['γ E2'])
result['gamma_error_sys'] = result['name'].map(gamma_sys_dict)
result['gamma_error'] = np.sqrt(result['gamma_error_uncorr']**2 + result['gamma_error_sys']**2)
result['r_eff'] = result['r_eff']
result['r_eff_error_uncorr'] = 0.5*(result['r_eff_e1'] + result['r_eff_e2'])
result['r_eff_error'] = np.sqrt(result['r_eff_error_uncorr']**2 + (0.02*result['r_eff'])**2)
result['z_lens'] = result['name'].map(z_lens_dict)
result['z_source'] = result['name'].map(z_source_dict)
result['sigma_v'] = result['name'].map(v_disp_dict)
result['sigma_v_error'] = result['name'].map(v_disp_err_dict)

result_cut = result[['name','z_lens','z_source','sigma_v','sigma_v_error',
        'theta_E','theta_E_error','gamma','gamma_error','r_eff','r_eff_error','light_model',
        'r_sersic_1','n_sersic_1','amp_sersic_1','r_sersic_2','n_sersic_2','amp_sersic_2'] ]  


####### Hack to get SDSSJ2347-0005 velocity dispersion
result_cut.at[33, 'sigma_v'] = list(df[df['name']=='SDSSJ2347-0005']['sigma_v'])[0]
result_cut.at[33, 'sigma_v_error'] = list(df[df['name']=='SDSSJ2347-0005']['sigma_v_error'])[0]



result_cut.to_csv('SLACS_all_params.csv',index=False)

#name,flag_imaging_tan23,z_lens,z_source,sigma_v,sigma_v_error,theta_E,theta_E_error,gamma,gamma_error,r_eff,r_eff_err

# %%
result_cut
# Out:
#               name  z_lens  z_source     sigma_v  sigma_v_error  theta_E  \
# 0   SDSSJ0008-0004   0.440     1.192  227.746450      27.228525    1.225
# 1   SDSSJ0029-0055   0.227     0.931  215.761016      14.837630    0.945
# 2   SDSSJ0037-0942   0.195     0.632  264.698470       7.797912    1.476
# 3   SDSSJ0252+0039   0.280     0.982  193.123171       9.869020    1.028
# 4   SDSSJ0330-0020   0.351     1.071  273.237471      22.915758    1.094
# 5   SDSSJ0728+3835   0.206     0.688  209.868956       8.056450    1.261
# 6   SDSSJ0737+3216   0.322     0.581  313.636996      10.769591    0.963
# 7   SDSSJ0819+4534   0.194     0.446  231.647709      12.745777    0.784
# 8   SDSSJ0903+4116   0.430     1.065  270.395273      21.277548    1.275
# 9   SDSSJ0912+0029   0.164     0.324  301.184276       8.973282    1.609
# 10  SDSSJ0936+0913   0.190     0.588  227.134107       8.412815    1.096
# 11  SDSSJ0959+0410   0.126     0.535  192.127524       8.820169    0.960
# 12  SDSSJ1023+4230   0.191     0.696  271.563252      11.960961    1.400
# 13  SDSSJ1100+5329   0.317     0.858  210.838236      17.790741    1.461
# 14  SDSSJ1112+0826   0.273     0.629  260.411389      14.607055    1.497
# 15  SDSSJ1134+6027   0.153     0.474  238.582229       7.737061    1.243
# 16  SDSSJ1204+0358   0.164     0.631  250.614456      12.436070    1.295
# 17  SDSSJ1213+6708   0.123     0.640  267.422805       7.397096    1.451
# 18  SDSSJ1218+0830   0.135     0.717  221.879719       6.809761    1.489
# 19  SDSSJ1250+0523   0.232     0.795  242.305727      10.291973    1.120
# 20  SDSSJ1306+0600   0.173     0.472  247.961417      13.556774    1.312
# 21  SDSSJ1313+4615   0.185     0.514  258.869159      12.695142    1.290
# 22  SDSSJ1402+6321   0.205     0.481  273.865610      11.055306    1.371
# 23  SDSSJ1531-0105   0.160     0.744  261.317176      10.229606    1.712
# 24  SDSSJ1621+3931   0.245     0.602  233.902525      14.559589    1.266
# 25  SDSSJ1627-0053   0.208     0.524  274.266097      10.596846    1.221
# 26  SDSSJ1630+4520   0.248     0.793  282.871021      13.091890    1.791
# 27  SDSSJ1636+4707   0.228     0.675  223.128912      10.282131    1.084
# 28  SDSSJ2238-0754   0.137     0.713  225.760576       8.198847    1.270
# 29  SDSSJ2300+0022   0.228     0.463  299.693537      13.348629    1.232
# 30  SDSSJ2302-0840   0.090     0.222  259.014500       6.226636    1.038
# 31  SDSSJ2303+1422   0.155     0.517  250.781472      12.575501    1.622
# 32  SDSSJ2343-0030   0.181     0.463  254.561822       8.698907    1.506
# 33  SDSSJ2347-0005   0.417     0.714  404.000000      59.000000    1.077
#
#     theta_E_error  gamma  gamma_error  r_eff  r_eff_error    light_model  \
# 0          0.0085   1.75     0.351249  1.926       0.0275  single_sersic
# 1          0.0030   2.69     0.250363  2.386       0.0050  double_sersic
# 2          0.0085   2.38     0.111860  3.334       0.0470  double_sersic
# 3          0.0010   1.55     0.129352  1.485       0.0050  single_sersic
# 4          0.0030   2.14     0.167204  1.243       0.0045  single_sersic
# 5          0.0025   1.64     0.244985  1.899       0.0030  single_sersic
# 6          0.0010   2.32     0.206004  2.828       0.0145  single_sersic
# 7          0.0070   1.84     0.216286  3.063       0.0080  double_sersic
# 8          0.0015   2.17     0.038036  2.982       0.0700  double_sersic
# 9          0.0015   1.58     0.062841  4.210       0.0055  single_sersic
# 10         0.0030   2.21     0.086027  2.108       0.0060  double_sersic
# 11         0.0020   2.22     0.088578  0.968       0.0010  double_sersic
# 12         0.0020   2.22     0.152282  1.969       0.0030  single_sersic
# 13         0.0030   1.89     0.145528  2.261       0.0060  single_sersic
# 14         0.0105   1.92     0.178227  1.623       0.0030  single_sersic
# 15         0.0045   1.75     0.197002  1.899       0.0070  double_sersic
# 16         0.0025   2.02     0.055965  1.544       0.0040  double_sersic
# 17         0.0050   1.71     0.218302  2.771       0.0030  double_sersic
# 18         0.0075   1.96     0.100968  3.506       0.0210  double_sersic
# 19         0.0010   2.18     0.089692  1.748       0.0040  single_sersic
# 20         0.0060   1.97     0.070144  2.369       0.0060  single_sersic
# 21         0.0055   2.18     0.084613  2.170       0.0050  single_sersic
# 22         0.0025   1.57     0.300836  2.720       0.0060  single_sersic
# 23         0.0065   2.07     0.254001  3.416       0.0190  double_sersic
# 24         0.0040   2.02     0.071364  2.402       0.0080  double_sersic
# 25         0.0010   1.93     0.136410  2.981       0.0545  double_sersic
# 26         0.0010   1.92     0.086124  2.012       0.0055  single_sersic
# 27         0.0025   1.75     0.171981  1.837       0.0030  single_sersic
# 28         0.0010   2.34     0.126890  2.520       0.0050  single_sersic
# 29         0.0040   1.66     0.220391  1.815       0.0070  single_sersic
# 30         0.0010   2.60     0.085508  4.199       0.0350  double_sersic
# 31         0.0020   1.94     0.079637  3.640       0.0085  single_sersic
# 32         0.0020   2.16     0.126428  2.372       0.0045  single_sersic
# 33         0.0045   1.98     0.074504  1.441       0.0060  single_sersic
#
#     r_sersic_1  n_sersic_1  amp_sersic_1  r_sersic_2  n_sersic_2  amp_sersic_2
# 0     1.925683         4.0      0.243889         NaN         NaN           NaN
# 1     0.935352         4.0      2.954257    4.120641         1.0      0.292315
# 2     1.785753         4.0      2.918359   11.892235         1.0      0.051165
# 3     1.485519         4.0      0.892217         NaN         NaN           NaN
# 4     1.243227         4.0      0.967232         NaN         NaN           NaN
# 5     1.899198         4.0      1.898282         NaN         NaN           NaN
# 6     2.827935         4.0      3.566769         NaN         NaN           NaN
# 7     0.887582         4.0      3.493566    5.570926         1.0      0.201249
# 8     1.035708         4.0      1.049496    6.039004         1.0      0.054465
# 9     4.210354         4.0     10.572976         NaN         NaN           NaN
# 10    1.162788         4.0      3.996020    3.913771         1.0      0.402911
# 11    0.494831         4.0     69.537784    1.287825         1.0     25.199346
# 12    1.969764         4.0      1.887220         NaN         NaN           NaN
# 13    2.259480         4.0      0.785495         NaN         NaN           NaN
# 14    1.623640         4.0      1.637645         NaN         NaN           NaN
# 15    1.081856         4.0      5.340157    4.240757         1.0      0.313128
# 16    0.903355         4.0      5.240864    2.821609         1.0      0.566275
# 17    1.111984         4.0      8.097224    4.835037         1.0      0.792109
# 18    2.217516         4.0      2.850465    8.380169         1.0      0.139734
# 19    1.749358         4.0     18.224783         NaN         NaN           NaN
# 20    2.371579         4.0      1.327322         NaN         NaN           NaN
# 21    2.171118         4.0      1.810464         NaN         NaN           NaN
# 22    2.721397         4.0     11.036313         NaN         NaN           NaN
# 23    1.651398         4.0      3.226338    8.085098         1.0      0.148252
# 24    1.176378         4.0      2.692809    4.701743         1.0      0.215805
# 25    1.235924         4.0     19.230467    6.865504         1.0      0.836410
# 26    2.012298         4.0     11.873655         NaN         NaN           NaN
# 27    1.837489         4.0      1.649255         NaN         NaN           NaN
# 28    2.519016         4.0     16.467900         NaN         NaN           NaN
# 29    1.814653         4.0     11.013489         NaN         NaN           NaN
# 30    1.573718         4.0      6.627191   10.103811         1.0      0.230193
# 31    3.639833         4.0      7.117140         NaN         NaN           NaN
# 32    2.372416         4.0      1.582909         NaN         NaN           NaN
# 33    1.440590         4.0      0.847084         NaN         NaN           NaN

# %%
df = pd.read_csv('../v9_Sluse/old_params/sl2s_all_params.csv')
z_lens_dict = {}
z_source_dict = {}
v_disp_dict = {}
v_disp_err_dict = {}
slit_dict = {}
width_dict = {}
seeing_dict = {}


for index, row in df.iterrows():
   # print(row['name'], row['z_lens'], row['z_source'])
    z_lens_dict[row['name']] = row['z_lens']
    z_source_dict[row['name']] = row['z_source']
    v_disp_dict[row['name']] = row['sigma_v']
    v_disp_err_dict[row['name']] = row['sigma_v_error']
    slit_dict[row['name']] = row['slit']
    width_dict[row['name']] = row['width']
    seeing_dict[row['name']] = row['seeing']

# %%
mass_df = pd.read_csv('/home/s1/chinyi/80bdata/dinos/final_paper_figures/2_data_tables/tables/SL2S_Gold_mass_params.csv')
light_df = pd.read_csv('/home/s1/chinyi/80bdata/dinos/final_paper_figures/2_data_tables/tables/SL2S_Gold_light_params.csv')
result = pd.merge(mass_df, light_df,left_on="Lens Name",right_on="lens_name")

# %%
result['name'] = result['Lens Name']
result['theta_E'] = result['R_Ein']
result['theta_E_error'] = 0.5*(result['R_Ein E1'] + result['R_Ein E2'])
result['gamma'] = result['γ']
result['gamma_error_uncorr'] = 0.5*(result['γ E1'] + result['γ E2'])
result['gamma_error_sys'] = result['name'].map(gamma_sys_dict)
result['gamma_error'] = np.sqrt(result['gamma_error_uncorr']**2 + result['gamma_error_sys']**2)
result['r_eff'] = result['r_eff']
result['r_eff_error_uncorr'] = 0.5*(result['r_eff_e1'] + result['r_eff_e2'])
result['r_eff_error'] = np.sqrt(result['r_eff_error_uncorr']**2 + (0.02*result['r_eff'])**2)
result['z_lens'] = result['name'].map(z_lens_dict)
result['z_source'] = result['name'].map(z_source_dict)
result['sigma_v'] = result['name'].map(v_disp_dict)
result['sigma_v_error'] = result['name'].map(v_disp_err_dict)
result['slit'] = result['name'].map(slit_dict)
result['width'] = result['name'].map(width_dict)
result['seeing'] = result['name'].map(seeing_dict)

result_cut = result[['name','slit','width','seeing','z_lens','z_source','sigma_v','sigma_v_error',
        'theta_E','theta_E_error','gamma','gamma_error','r_eff','r_eff_error','light_model',
                      'r_sersic_1','n_sersic_1','amp_sersic_1','r_sersic_2','n_sersic_2','amp_sersic_2'] ]  

result_cut.to_csv('SL2S_all_params.csv',index=False)

#name,flag_imaging_tan23,z_lens,z_source,sigma_v,sigma_v_error,theta_E,theta_E_error,gamma,gamma_error,r_eff,r_eff_err

# %%
result_cut
# Out:
#               name  slit  width  seeing  z_lens  z_source  sigma_v  \
# 0   SL2SJ0208-0714   1.0   1.62     1.0   0.428     -1.00    295.0
# 1   SL2SJ0214-0405   1.0   1.88     0.8   0.609      1.88    287.0
# 2   SL2SJ0217-0513   1.5   1.68     0.6   0.646      1.85    239.0
# 3   SL2SJ0219-0829   1.0   1.68     0.7   0.389      2.15    289.0
# 4   SL2SJ0225-0454   1.0   0.81     0.7   0.238      1.20    234.0
# 5   SL2SJ0226-0420   1.0   1.62     0.6   0.494      1.23    263.0
# 6   SL2SJ0226-0406   1.5   1.68     0.6   0.766     -1.00    333.0
# 7   SL2SJ0232-0408   1.0   1.68     0.7   0.352      2.34    281.0
# 8   SL2SJ0849-0412   0.9   1.60     0.9   0.722      1.54    320.0
# 9   SL2SJ0849-0251   0.9   1.60     0.8   0.274      2.09    276.0
# 10  SL2SJ0858-0143   1.0   1.62     0.9   0.580     -1.00    233.0
# 11  SL2SJ0901-0259   0.9   1.60     0.7   0.670      1.19     -1.0
# 12  SL2SJ0904-0059   0.9   1.60     0.7   0.611      2.36    183.0
# 13  SL2SJ0959+0206   0.9   1.60     0.7   0.552      3.35    188.0
# 14  SL2SJ1358+5459   1.0   1.62     0.8   0.510     -1.00    287.0
# 15  SL2SJ1359+5535   1.0   1.62     0.7   0.783      2.77    228.0
# 16  SL2SJ1401+5544   1.0   1.62     0.8   0.464     -1.00    297.0
# 17  SL2SJ1402+5505   NaN    NaN     NaN   0.412     -1.00     -1.0
# 18  SL2SJ1405+5243   1.0   1.62     0.8   0.526      3.01    284.0
# 19  SL2SJ1406+5226   1.0   1.62     0.9   0.716      1.47    253.0
# 20  SL2SJ1411+5651   1.0   1.62     1.3   0.322      1.42    214.0
# 21  SL2SJ1420+5630   1.0   1.62     0.9   0.483      3.12    228.0
# 22  SL2SJ1427+5516   1.0   1.62     0.8   0.511      2.58     -1.0
# 23  SL2SJ2214-1807   1.0   1.68     0.7   0.651     -1.00    200.0
#
#     sigma_v_error  theta_E  theta_E_error  gamma  gamma_error  r_eff  \
# 0            27.0    2.583         0.0235   1.98     0.076356  2.092
# 1            47.0    1.221         0.0060   1.86     0.331058  1.184
# 2            27.0    1.258         0.0030   2.34     0.241506  0.681
# 3            23.0    1.285         0.0070   2.62     0.150504  0.881
# 4            21.0    1.716         0.0195   1.96     0.118134  2.550
# 5            24.0    1.099         0.0140   2.14     0.126285  0.890
# 6            24.0    1.289         0.0160   2.02     0.225032  0.884
# 7            26.0    1.012         0.0065   2.49     0.248844  1.128
# 8            24.0    1.074         0.0120   2.26     0.185287  0.602
# 9            35.0    1.192         0.0080   2.24     0.303645  1.539
# 10           25.0    0.953         0.0245   2.09     0.456036  1.257
# 11           -1.0    0.997         0.0435   2.11     0.092492  0.704
# 12           21.0    1.381         0.0145   2.24     0.220535  2.255
# 13           22.0    0.724         0.0100   2.16     0.375349  0.465
# 14           22.0    1.241         0.0135   2.08     0.082532  1.024
# 15           29.0    1.107         0.0135   1.95     0.304103  2.567
# 16           22.0    1.924         0.0120   2.03     0.187620  1.637
# 17           -1.0    1.233         0.0105   1.76     0.253698  1.589
# 18           21.0    1.431         0.0080   1.72     0.131179  1.020
# 19           19.0    1.034         0.0105   1.91     0.263762  0.828
# 20           23.0    0.920         0.0020   1.75     0.308434  0.574
# 21           19.0    1.391         0.0055   2.06     0.224573  1.788
# 22           -1.0    0.926         0.0135   2.29     0.336165  0.267
# 23           24.0    0.807         0.1845   2.20     0.360443  0.939
#
#     r_eff_error    light_model  amp_sersic_1  r_sersic_2  n_sersic_2  \
# 0        0.0310  double_sersic     69.166633    4.313815         1.0
# 1        0.0395  single_sersic      3.669074         NaN         NaN
# 2        0.0150  single_sersic     10.141981         NaN         NaN
# 3        0.0060  double_sersic    155.672135    1.789168         1.0
# 4        0.0125  single_sersic      0.973812         NaN         NaN
# 5        0.0135  single_sersic      0.832110         NaN         NaN
# 6        0.0350  single_sersic      0.228616         NaN         NaN
# 7        0.0120  single_sersic      0.705478         NaN         NaN
# 8        0.0080  single_sersic     18.299714         NaN         NaN
# 9        0.0105  single_sersic      0.948022         NaN         NaN
# 10       0.0760  single_sersic      0.110014         NaN         NaN
# 11       0.0520  single_sersic      0.154841         NaN         NaN
# 12       0.0885  single_sersic      0.061527         NaN         NaN
# 13       0.0135  single_sersic      0.704995         NaN         NaN
# 14       0.0275  single_sersic      0.361530         NaN         NaN
# 15       0.1545  single_sersic      0.024026         NaN         NaN
# 16       0.0090  single_sersic     13.208840         NaN         NaN
# 17       0.0075  single_sersic     18.273658         NaN         NaN
# 18       0.0175  single_sersic      0.528487         NaN         NaN
# 19       0.0435  single_sersic      0.220516         NaN         NaN
# 20       0.0025  single_sersic     72.622326         NaN         NaN
# 21       0.0120  single_sersic     10.473037         NaN         NaN
# 22       0.0030  double_sersic      3.115244    0.312579         1.0
# 23       0.0415  single_sersic      0.209967         NaN         NaN
#
#     amp_sersic_2
# 0       2.938341
# 1            NaN
# 2            NaN
# 3       6.073850
# 4            NaN
# 5            NaN
# 6            NaN
# 7            NaN
# 8            NaN
# 9            NaN
# 10           NaN
# 11           NaN
# 12           NaN
# 13           NaN
# 14           NaN
# 15           NaN
# 16           NaN
# 17           NaN
# 18           NaN
# 19           NaN
# 20           NaN
# 21           NaN
# 22      2.573764
# 23           NaN
