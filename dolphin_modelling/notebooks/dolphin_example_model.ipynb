# %%
import yaml
import numpy as np
import matplotlib.pyplot as plt
import seaborn
import h5py
from dolphin.analysis.output import Output

output = Output('../')

# %%
def Outputer(lens_name,model_id):

    with open('../settings/{}_config.yml'.format(lens_name)) as file:
        lens_list = yaml.load(file, Loader=yaml.FullLoader)
        
    for i, band in enumerate(lens_list['band']):
        fig = output.plot_model_overview(lens_name=lens_name, model_id=model_id,band_index=i,
                                         print_results=False,
                                        background_v_min=-0.5,source_v_min_offset=-1.0)
        plt.show()
    return None

# %%
Outputer('SL2SJ1359+5535','dinos-i')
# Out:
# -0.7946680987201307 reduced X^2 of all evaluated imaging data combined (without degrees of freedom subtracted).
# reduced chi^2 of data  0 =  0.7946680987201333
# /home/s1/chinyi/mybin/lenstronomy/lenstronomy/Plots/model_band_plot.py:44: RuntimeWarning: divide by zero encountered in log10
#   log_model = np.log10(model)
# /home/s1/chinyi/mybin/lenstronomy/lenstronomy/Plots/model_band_plot.py:44: RuntimeWarning: invalid value encountered in log10
#   log_model = np.log10(model)
# /home/s1/chinyi/mybin/lenstronomy/lenstronomy/Plots/plot_util.py:241: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. In future versions, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = copy.copy(mpl.cm.get_cmap("cubehelix"))
#   cmap.set_bad(color='k', alpha=1.)
# /home/s1/chinyi/mybin/lenstronomy/lenstronomy/Plots/plot_util.py:242: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. In future versions, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = copy.copy(mpl.cm.get_cmap("cubehelix"))
#   cmap.set_under('k')
# /home/s1/chinyi/mybin/lenstronomy/lenstronomy/Plots/model_band_plot.py:103: RuntimeWarning: invalid value encountered in log10
#   im = ax.matshow(np.log10(self._data), origin='lower',
# /home/s1/chinyi/mybin/lenstronomy/lenstronomy/Plots/model_band_plot.py:141: RuntimeWarning: divide by zero encountered in log10
#   im = ax.matshow(np.log10(self._model), origin='lower', vmin=v_min, vmax=v_max,
# /home/s1/chinyi/mybin/lenstronomy/lenstronomy/Plots/model_band_plot.py:141: RuntimeWarning: invalid value encountered in log10
#   im = ax.matshow(np.log10(self._model), origin='lower', vmin=v_min, vmax=v_max,
