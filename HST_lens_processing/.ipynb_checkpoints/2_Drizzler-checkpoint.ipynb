# %%
import numpy as np
import pandas as pd

import glob
import shutil
import os
import matplotlib.pyplot as plt
import numpy as np
from scipy import ndimage
import subprocess

from astropy.io import fits
from astropy.table import Table
from astroquery.mast import Observations
from astropy.visualization import LogStretch
from astropy.visualization import ImageNormalize
from astropy.visualization import LinearStretch
from astropy import wcs
from drizzlepac import astrodrizzle
from drizzlepac import tweakreg
from drizzlepac import photeq

from stwcs.updatewcs import updatewcs
from stsci.skypac import skymatch


import matplotlib
# Out:
# The following task in the stsci.skypac package can be run with TEAL:
#                                     skymatch
# The following tasks in the drizzlepac package can be run with TEAL:
#     astrodrizzle       config_testbed      imagefindpars           mapreg
#        photeq            pixreplace           pixtopix            pixtosky
#   refimagefindpars       resetbits          runastrodriz          skytopix
#      tweakback            tweakreg           updatenpol

# %%
def UV_Drizzle(object_name,band,camera,pixel_size):  # For ACS and WFC3 UVIS Image

    #Define raw and output data directory
    raw_data_dir = os.path.join(Main_dir, '{}/{}_{}/raw_data/'.format(object_name,band,camera))
    output_data_dir = os.path.join(Main_dir, '{}/{}_{}/reduced_data/'.format(object_name,band,camera))
    
    if not(os.path.isdir(output_data_dir)):
        os.mkdir(output_data_dir)
    
    # create temp working directory in output_dir
    temp_dir = output_data_dir + 'temp'

    if os.path.isdir(temp_dir):
        shutil.rmtree(temp_dir)
    os.mkdir(temp_dir)

    for file in glob.glob(os.path.join(raw_data_dir, "*.fits")):  # move raw data files to temporary directory
        shutil.copy2(file, temp_dir)
        

        

    # Run tweakreg to check allignment       
    tweakreg.TweakReg(temp_dir+'/*flc.fits',
                  enforce_user_order=False,
                  imagefindcfg={'threshold': 100, 'conv_width': 3.5, 'dqbits': ~4096},
                  refimagefindcfg={'threshold': 50, 'conv_width': 2.5},
                  shiftfile=True,
                  outshifts=temp_dir+'/shift814_flc.txt',
                  searchrad=5.0,
                  ylimit=0.6,
                  updatehdr=False,
                  wcsname='UVIS_FLC',
                  reusename=True,
                  interactive=False)
    
    # Start Drizzle
        
    short_exposures = []
    long_exposures = []
    time_threshold = 100
    
    flc_files = glob.glob(temp_dir+'/*flc.fits')
    for flc_file in flc_files:
        with fits.open(flc_file) as hdu:
            exp_time = hdu[0].header['EXPTIME']
            if exp_time < time_threshold:
                short_exposures.append(flc_file)
            else:
                long_exposures.append(flc_file)
            
    print('Short exposures: ', short_exposures)
    print('Long exposures: ', long_exposures)
    
    output = output_data_dir + object_name + '_' + band

    # First run cosmic ray detection for short exposures.
    astrodrizzle.AstroDrizzle(short_exposures,
 
                          # other parameters
                          output=output,
                          build=False, # if False, outputs sci, wht, and ctx into separate files
                          resetbits=0, # default 4096
                          
                          # state of input files
                          clean=False, # default False, True removes temporary files after finish
                          preserve=False,
                          
                          # step 1: static mask
                          static=True,
                          #static_sig=4., #default 4.
                          
                          # step 2: sky subtraction
                          skysub=True,
                          
                          # step 3: drizzle separate images
                          driz_separate=True,
                          driz_sep_kernel='turbo', # default 'turbo'
                          driz_sep_pixfrac=1., # default 1.
                          driz_sep_bits=0, # default 0
                          
                          # step 3a: custom WCS for separate outputs
                          driz_sep_scale=None, # default None
                          
                          # step 4: create median image
                          median=True, # default True
                          
                          # step 5: blot back the median image
                          blot=True, # default 
                          
                          # step 6: remove cosmic rays with deriv, driz_cr
                          driz_cr=True, # default True
                          driz_cr_corr=False, # default False
                          driz_cr_scale='2.15 0.7', # default '1.2 0.7'
                          # current value doesn't falsely detect 
                          # the central pixels of the quasar images as CR. 
                          
                          # step 7: drizzle final combined image
                          driz_combine=False, # default True
                          final_wht_type='EXP',
                          final_kernel='gaussian',
                          final_wt_scl='exptime',
                          final_pixfrac=1.,
                          final_bits='0', # default 0, adding back warm pixels (64) and 
                          
                          # step 7a: custom wcs for final output
                          final_wcs=False, # default False
                       #   final_rot=0,
                          final_scale=pixel_size,
                          
                          # instrument parameters
                          
                          # advanced parameters
    )

    # Then run cosmic ray detection for long exposures.
    astrodrizzle.AstroDrizzle(long_exposures,
                          
                          # other parameters
                          output=output,
                          build=False, # if False, outputs sci, wht, and ctx into separate files
                          resetbits=0, # default 4096
                          
                          # state of input files
                          clean=False, # default False
                          preserve=False,
                          
                          # step 1: static mask
                          static=True,
                          #static_sig=4., #default 4.
                          
                          # step 2: sky subtraction
                          skysub=True,
                          
                          # step 3: drizzle separate images
                          driz_separate=True,
                          driz_sep_kernel='turbo', # default 'turbo'
                          driz_sep_pixfrac=1., # default 1.
                          driz_sep_bits=0, # default 0
                          
                          # step 3a: custom WCS for separate outputs
                          driz_sep_scale=None, # default None
                          
                          # step 4: create median image
                          median=True, # default True
                          
                          # step 5: blot back the median image
                          blot=True, # default 
                          
                          # step 6: remove cosmic rays with deriv, driz_cr
                          driz_cr=True, # default True
                          driz_cr_corr=False, # default False
                          driz_cr_scale='2.25 0.7', # default '1.2 0.7'
                          # current value doesn't falsely detect 
                          # the central pixels of the quasar images as CR. 
                          
                          # step 7: drizzle final combined image
                          driz_combine=False, # default True
                          final_wht_type='EXP',
                          final_kernel='gaussian',
                          final_wt_scl='exptime',
                          final_pixfrac=1.,
                          final_bits='0', # default 0, adding back warm pixels (64) and 
                          
                          # step 7a: custom wcs for final output
                          final_wcs=False, # default False, should be set to True for final build
                       #   final_rot=0,
                          final_scale=pixel_size,
                          
                          # instrument parameters
                          
                          # advanced parameters
    )

    # Copy the cosmic ray masks for each exposures into respective flc file, flag the cosmic ray with DQ=8192.

    for flc_file in flc_files:
        file_id = flc_file.split('/')[-1].split('_')[0]
    
        with fits.open(flc_file) as hdu:
            hdu = fits.open(flc_file)

            with fits.open(temp_dir+'/{}_sci1_crmask.fits'.format(file_id)) as cr_hdu:
                cr_mask1 = cr_hdu[0].data.copy()
            with fits.open(temp_dir+'/{}_sci2_crmask.fits'.format(file_id)) as cr_hdu:
                cr_mask2 = cr_hdu[0].data.copy()

            hdu[3].data = np.bitwise_or(hdu[3].data, (1-cr_mask1)*8192)
            hdu[6].data = np.bitwise_or(hdu[6].data, (1-cr_mask2)*8192)
        
            hdu.writeto(flc_file, overwrite=True)

    # Drizzle the final image.
    output = output_data_dir + object_name + '_' + band
    astrodrizzle.AstroDrizzle(flc_files,
                          
                          # other parameters
                          output=output,
                          build=False, # if False, outputs sci, wht, and ctx into separate files
                          #resetbits=0, # default 4096
                          
                          # state of input files
                          clean=False, # default False
                          preserve=False,
                          
                          # step 1: static mask
                          static=True,
                          static_sig=4., #default 4.
                          
                          # step 2: sky subtraction
                          skysub=True,
                          
                          # step 3: drizzle separate images
                          driz_separate=False,
                          driz_sep_kernel='turbo', # default 'turbo'
                          driz_sep_pixfrac=1., # default 1.
                          driz_sep_bits=0, # default 0
                          
                          # step 3a: custom WCS for separate outputs
                          driz_sep_scale=None, # default None
                          
                          # step 4: create median image
                          median=False, # default True
                          
                          # step 5: blot back the median image
                          blot=False, # default 
                          
                          # step 6: remove cosmic rays with deriv, driz_cr
                          driz_cr=False, # default True
                          driz_cr_corr=False, # default False
                          driz_cr_scale='1.2 0.7', # default '1.2 0.7'
                          
                          # step 7: drizzle final combined image
                          driz_combine=True, # default True
                          final_wht_type='EXP',
                          final_kernel='gaussian',
                          final_wt_scl='exptime',
                          final_pixfrac=1.,
                          final_bits='16, 64', # default 0
                          # adding back warm pixels (DQ = 64) and hot stable pixels (DQ = 16)
                          
                          # step 7a: custom wcs for final output
                          final_wcs=True, # default False
                         # final_rot=0,
                          final_scale=pixel_size,
                          
                          # instrument parameters
                          
                          # advanced parameters
                          updatewcs=False, # default False
    )

    # Remove all the files in the notebook directory with the following suffixes.
    files_to_clean = ['coo', 'png', 'fits', 'match', 'log', 'list']

    for suffix in files_to_clean:
        filelist = glob.glob("./*.{}".format(suffix))

        for file in filelist:
            os.remove(file)
        
    if os.path.isdir(temp_dir): # Remove temporary directory 
        shutil.rmtree(temp_dir)
    
    filelist = glob.glob(output_data_dir+'/*med.fits') # Remove median files created at CR detection stage.
    for file in filelist:
        os.remove(file)

# %%
def IR_Drizzler(object_name,band,camera,pixel_size):  # For WFC3 IR Image

    raw_data_dir = os.path.join(Main_dir, '{}/{}_{}/raw_data/'.format(object_name,band,camera))
    output_data_dir = os.path.join(Main_dir, '{}/{}_{}/reduced_data/'.format(object_name,band,camera))
    
    if not(os.path.isdir(output_data_dir)):
        os.mkdir(output_data_dir)
    
    # create temp working directory in output_dir
    temp_dir = output_data_dir + 'temp'

    if os.path.isdir(temp_dir):
        shutil.rmtree(temp_dir)
    
    os.mkdir(temp_dir)

    # move raw data files to temporary directory to work on
    for file in glob.glob(os.path.join(raw_data_dir, "*.fits")):
        shutil.copy2(file, temp_dir)
    


 #Check Aligment

    tweakreg.TweakReg(temp_dir+'/*flt.fits',
                  imagefindcfg={'threshold': 50, 'conv_width': 2.5},
                  expand_refcat=True,
                  enforce_user_order=False,
                  shiftfile=True,
                  outshifts=temp_dir+'/shift160_flt.txt',
                  searchrad=2.0,
                  ylimit=0.3,
                  updatehdr=False,
                  reusename=True,
                  wcsname='IR_FLT',
                  interactive=False)

    
 #Drizzle
    output = output_data_dir + '/' + object_name + '_' + band
    astrodrizzle.AstroDrizzle(temp_dir+'/*flt.fits',
                          
                          # other parameters
                          output=output,
                          build=False, # if False, outputs sci, wht, and ctx into separate files
                          #resetbits=0, # default 4096
                          
                          # state of input files
                          preserve=False, # default True
                          clean=True, # default False
                          
                          # step 1: static mask
                          static=True,
                          static_sig=4., #default 4.
                          
                          # step 2: sky subtraction
                          skysub=False,
                          
                          # step 3: drizzle separate images
                          driz_separate=True,
                          driz_sep_kernel='turbo', # default 'turbo'
                          driz_sep_pixfrac=1., # default 1.
                          driz_sep_bits=0, # default 0
                          
                          # step 3a: custom WCS for separate outputs
                          driz_sep_scale=None, # default None
                          
                          # step 4: create median image
                          median=True, # default True
                          
                          # step 5: blot back the median image
                          blot=True, # default True
                          
                          # step 6: remove cosmic rays with deriv, driz_cr
                          driz_cr=True, # default True
                          driz_cr_corr=False, # default False
                          driz_cr_scale='2.2 0.7', # default '1.2 0.7'
                          #current value doesn't falsely detect
                          # the central pixels of the quasar images as CR. 
                          #driz_cr_snr='2. 1.5',
                          
                          # step 7: drizzle final combined image
                          driz_combine=True,
                          final_wht_type='EXP',
                          final_kernel='gaussian',
                          final_wt_scl='exptime',
                          final_pixfrac=0.7,
                          final_bits=64, # default 0, including warm pixels (DQ=64) back
                          
                          # step 7a: custom wcs for final output
                          final_wcs=True, # default False
                          final_rot=0,
                          final_scale=pixel_size,
                          
                          # instrument parameters
                          
                          # advanced parameters
    )
 

# Remove all the files in the notebook directory with the following suffixes.
    files_to_clean = ['coo', 'png', 'fits', 'match', 'log', 'list']

    for suffix in files_to_clean:
        filelist = glob.glob("./*.{}".format(suffix))

        for file in filelist:
            os.remove(file)
        
# Remove temporary directory.
    if os.path.isdir(temp_dir):
        shutil.rmtree(temp_dir)
    
# Remove median files created at cosmic ray detection stage.
    filelist = glob.glob(output_data_dir+'/*med.fits')

    for file in filelist:
        os.remove(file)

# %%
def WFPC2_Drizzle(object_name,band,camera,pixel_size): # For WFPC2 UV Image
    print("Processing Lens : "+object_name,band,camera)
    
    raw_data_dir = os.path.join(Main_dir, '{}/{}_{}/raw_data/'.format(object_name,band,camera))
    output_data_dir = os.path.join(Main_dir, '{}/{}_{}/reduced_data/'.format(object_name,band,camera))
    current_dir= "./"

   
    # Copy file to working directory
    filelist = glob.glob("./*.fits") # Remove previous fits files
    for file in filelist:
        os.remove(file)
    
    for file in glob.glob(os.path.join(raw_data_dir, "*.fits")):
        shutil.copy2(file, current_dir)  


    if not(os.path.isdir(output_data_dir)):
        os.mkdir(output_data_dir)
    
    # Update WCS Information    
    for file in glob.glob(os.path.join(current_dir, "*.fits")):
        c0m_fits_name=(file)[2:9]
        
    os.environ['CRDS_SERVER_URL'] = 'https://hst-crds.stsci.edu'
    os.environ['CRDS_PATH'] = os.path.abspath(os.path.join('.', 'reference_files'))

    subprocess.check_output('crds bestrefs --files {}*_c0m.fits --sync-references=1 --update-bestrefs'.format(c0m_fits_name),
                            shell=True, stderr=subprocess.DEVNULL)

    os.environ['uref'] = os.path.abspath(os.path.join('.', 'reference_files', 'references', 'hst', 'wfpc2')) + os.path.sep        

    updatewcs('*c0m.fits', use_db=True)
    
    # Alligning the image    
    tweakreg.TweakReg('*c0m.fits', updatehdr=True, reusename=True, interactive=False,
                      conv_width=3.0, threshold=300.0, peakmin=100, peakmax=10000)  
    
    # Equalize the chip sensitivities
    photeq.photeq(files='*_c0m.fits', ref_phot_ext=3, readonly=False)
    
    # Drizzle
    astrodrizzle.AstroDrizzle('*c0m.fits',
                          preserve=False,
                          driz_sep_bits='8,1024',
                          driz_sep_wcs=True,
                          driz_sep_scale=0.0996,
                          combine_type='median',
                          driz_cr_snr='5.5 3.5',
                          driz_cr_scale='2.0 1.5',
                          final_fillval=None,
                          final_bits='8,1024',
                          final_wcs=True,
                        #  final_rot=0,
                          final_scale=pixel_size)
        
    #Move output files
    shutil.move("final_drz_sci.fits", output_data_dir+"{}_{}_drc_sci.fits".format(object_name,band))
    shutil.move("final_drz_ctx.fits", output_data_dir+"{}_{}_drc_ctx.fits".format(object_name,band))
    shutil.move("final_drz_wht.fits", output_data_dir+"{}_{}_drc_wht.fits".format(object_name,band))
    
    #Clean files in working directory
    files_to_clean = ['coo', 'png', 'fits', 'match', 'log', 'list']

    for suffix in files_to_clean:
        filelist = glob.glob("./*.{}".format(suffix))

        for file in filelist:
            os.remove(file)

# %%
def Single_Drizzler(object_name,band,camera,pixel_size): # For Single Exposure ACS UV Images

    raw_data_dir = os.path.join(Main_dir, '{}/{}_{}/raw_data/'.format(object_name,band,camera))
    output_data_dir = os.path.join(Main_dir, '{}/{}_{}/reduced_data/'.format(object_name,band,camera))
    
    if not(os.path.isdir(output_data_dir)):
        os.mkdir(output_data_dir)
    
    # create temp working directory in output_dir
    temp_dir = output_data_dir + 'temp'

    if os.path.isdir(temp_dir):
        shutil.rmtree(temp_dir)
    
    os.mkdir(temp_dir)

    # move raw data files to temporary directory to work on
    for file in glob.glob(os.path.join(raw_data_dir, "*.fits")):
        shutil.copy2(file, temp_dir)

#Part 2        
    flc_files = glob.glob(temp_dir+'/*flc.fits')

    
   # shift_table = Table.read(temp_dir+'/shift814_flc.txt',
   #                          format='ascii.no_header', 
   #                          names=['file', 'dx', 'dy', 'rot', 'scale', 'xrms', 'yrms'])
#
 #   formats = ['.2f', '.2f', '.3f', '.5f', '.2f', '.2f']
 #   for i, col in enumerate(shift_table.colnames[1:]):
 #       shift_table[col].format = formats[i]
        
    short_exposures = []
    long_exposures = []
    time_threshold = 100

    for flc_file in flc_files:
        with fits.open(flc_file) as hdu:
            exp_time = hdu[0].header['EXPTIME']
            short_exposures.append(flc_file)
            
    print('Short exposures: ', short_exposures)
    
    #Part 3
    output = output_data_dir + object_name + '_' + band
    # First run cosmic ray detection for short exposures.
    astrodrizzle.AstroDrizzle(short_exposures,
 
                          # other parameters
                          output=output,
                          build=False, # if False, outputs sci, wht, and ctx into separate files
                          resetbits=0, # default 4096
                          
                          # state of input files
                          clean=False, # default False, True removes temporary files after finish
                          preserve=False,
                          
                          # step 1: static mask
                          static=True,
                          #static_sig=4., #default 4.
                          
                          # step 2: sky subtraction
                          skysub=True,
                          
                          # step 3: drizzle separate images
                          driz_separate=True,
                          driz_sep_kernel='turbo', # default 'turbo'
                          driz_sep_pixfrac=1., # default 1.
                          driz_sep_bits=0, # default 0
                          
                          # step 3a: custom WCS for separate outputs
                          driz_sep_scale=None, # default None
                          
                          # step 4: create median image
                          median=False, # default True
                          
                          # step 5: blot back the median image
                          blot=False, # default 
                          
                          # step 6: remove cosmic rays with deriv, driz_cr
                          driz_cr=False, # default True
                          driz_cr_corr=False, # default False
                          driz_cr_scale='2.15 0.7', # default '1.2 0.7'
                          # current value doesn't falsely detect 
                          # the central pixels of the quasar images as CR. 
                          
                          # step 7: drizzle final combined image
                          driz_combine=True, # default True
                          final_wht_type='EXP',
                          final_kernel='gaussian',
                          final_wt_scl='exptime',
                          final_pixfrac=1.,
                          final_bits='0', # default 0, adding back warm pixels (64) and 
                          
                          # step 7a: custom wcs for final output
                          final_wcs=True, # default False
                       #   final_rot=0,
                          final_scale=pixel_size,
                          
                          # instrument parameters
                          
                          # advanced parameters
    )



# Remove all the files in the notebook directory with the following suffixes.
    files_to_clean = ['coo', 'png', 'fits', 'match', 'log', 'list']

    for suffix in files_to_clean:
        filelist = glob.glob("./*.{}".format(suffix))

        for file in filelist:
            os.remove(file)
        
    if os.path.isdir(temp_dir): # Remove temporary directory 
        shutil.rmtree(temp_dir)
    
    filelist = glob.glob(output_data_dir+'/*med.fits') # Remove median files created at CR detection stage.
    for file in filelist:
        os.remove(file)

# %%
#Configuration

Main_dir = '../lenses/'  # Lens Directory

WFC3_UV_PixelSize  = 0.04
ACS_UV_PixelSize   = 0.05

UV_Drizzle('SDSSJ1627-0053','F390W','WFC3',WFC3_UV_PixelSize)
UV_Drizzle('SDSSJ1627-0053','F555W','ACS',ACS_UV_PixelSize)
UV_Drizzle('SDSSJ1627-0053','F814W','ACS',ACS_UV_PixelSize)
# Out:
# Setting up logfile :  tweakreg.log
# TweakReg Version 1.4.7(18-April-2018) started at: 21:26:17.430 (26/01/2024)
#
# Version Information
# --------------------
# Python Version [GCC 7.3.0]
# 3.7.10 (default, Feb 26 2021, 18:47:35)
# numpy Version -> 1.19.2
# astropy Version -> 4.2
# stwcs Version -> 1.6.1
#
# Finding shifts for:
#     /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi21pgq_flc.fits
#     /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi21phq_flc.fits
#     /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi21pjq_flc.fits
#     /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi21plq_flc.fits
#     /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi22pnq_flc.fits
#     /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi22poq_flc.fits
#     /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi22pqq_flc.fits
#     /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi22psq_flc.fits
#     /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi23puq_flc.fits
#     /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi23pvq_flc.fits
#     /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi23pxq_flc.fits
#     /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi23pzq_flc.fits
#
# ===  Source finding for image '/data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi21pgq_flc.fits':
#   #  Source finding for '/data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi21pgq_flc.fits', EXT=('SCI', 1) started at: 21:26:17.612 (26/01/2024)
#      Found 4106 objects.
#   #  Source finding for '/data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi21pgq_flc.fits', EXT=('SCI', 2) started at: 21:26:19.019 (26/01/2024)
#      Found 4727 objects.
# ===  FINAL number of objects in image '/data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi21pgq_flc.fits': 8833
#
# ===  Source finding for image '/data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi21phq_flc.fits':
#   #  Source finding for '/data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi21phq_flc.fits', EXT=('SCI', 1) started at: 21:26:20.858 (26/01/2024)
#      Found 2804 objects.
#   #  Source finding for '/data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi21phq_flc.fits', EXT=('SCI', 2) started at: 21:26:22.195 (26/01/2024)
#      Found 2968 objects.
# ===  FINAL number of objects in image '/data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi21phq_flc.fits': 5772
#
# ===  Source finding for image '/data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi21pjq_flc.fits':
#   #  Source finding for '/data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi21pjq_flc.fits', EXT=('SCI', 1) started at: 21:26:23.909 (26/01/2024)
#      Found 2259 objects.
#   #  Source finding for '/data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi21pjq_flc.fits', EXT=('SCI', 2) started at: 21:26:25.208 (26/01/2024)
#      Found 2476 objects.
# ===  FINAL number of objects in image '/data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi21pjq_flc.fits': 4735
#
# ===  Source finding for image '/data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi21plq_flc.fits':
#   #  Source finding for '/data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi21plq_flc.fits', EXT=('SCI', 1) started at: 21:26:26.719 (26/01/2024)
#      Found 2124 objects.
#   #  Source finding for '/data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi21plq_flc.fits', EXT=('SCI', 2) started at: 21:26:28.096 (26/01/2024)
#      Found 2067 objects.
# ===  FINAL number of objects in image '/data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi21plq_flc.fits': 4191
#
# ===  Source finding for image '/data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi22pnq_flc.fits':
#   #  Source finding for '/data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi22pnq_flc.fits', EXT=('SCI', 1) started at: 21:26:29.519 (26/01/2024)
#      Found 2564 objects.
#   #  Source finding for '/data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi22pnq_flc.fits', EXT=('SCI', 2) started at: 21:26:30.798 (26/01/2024)
#      Found 3371 objects.
# ===  FINAL number of objects in image '/data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi22pnq_flc.fits': 5935
#
# ===  Source finding for image '/data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi22poq_flc.fits':
#   #  Source finding for '/data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi22poq_flc.fits', EXT=('SCI', 1) started at: 21:26:32.470 (26/01/2024)
#      Found 1912 objects.
#   #  Source finding for '/data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi22poq_flc.fits', EXT=('SCI', 2) started at: 21:26:33.697 (26/01/2024)
#      Found 1748 objects.
# ===  FINAL number of objects in image '/data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi22poq_flc.fits': 3660
#
# ===  Source finding for image '/data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi22pqq_flc.fits':
#   #  Source finding for '/data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi22pqq_flc.fits', EXT=('SCI', 1) started at: 21:26:35.12 (26/01/2024)
#      Found 2370 objects.
#   #  Source finding for '/data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi22pqq_flc.fits', EXT=('SCI', 2) started at: 21:26:36.388 (26/01/2024)
#      Found 2032 objects.
# ===  FINAL number of objects in image '/data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi22pqq_flc.fits': 4402
#
# ===  Source finding for image '/data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi22psq_flc.fits':
#   #  Source finding for '/data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi22psq_flc.fits', EXT=('SCI', 1) started at: 21:26:37.960 (26/01/2024)
#      Found 3837 objects.
#   #  Source finding for '/data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi22psq_flc.fits', EXT=('SCI', 2) started at: 21:26:39.331 (26/01/2024)
#      Found 3772 objects.
# ===  FINAL number of objects in image '/data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi22psq_flc.fits': 7609
#
# ===  Source finding for image '/data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi23puq_flc.fits':
#   #  Source finding for '/data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi23puq_flc.fits', EXT=('SCI', 1) started at: 21:26:41.017 (26/01/2024)
#      Found 2599 objects.
#   #  Source finding for '/data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi23puq_flc.fits', EXT=('SCI', 2) started at: 21:26:42.356 (26/01/2024)
#      Found 2304 objects.
# ===  FINAL number of objects in image '/data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi23puq_flc.fits': 4903
#
# ===  Source finding for image '/data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi23pvq_flc.fits':
#   #  Source finding for '/data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi23pvq_flc.fits', EXT=('SCI', 1) started at: 21:26:43.89 (26/01/2024)
#      Found 1960 objects.
#   #  Source finding for '/data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi23pvq_flc.fits', EXT=('SCI', 2) started at: 21:26:45.163 (26/01/2024)
#      Found 1848 objects.
# ===  FINAL number of objects in image '/data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi23pvq_flc.fits': 3808
#
# ===  Source finding for image '/data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi23pxq_flc.fits':
#   #  Source finding for '/data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi23pxq_flc.fits', EXT=('SCI', 1) started at: 21:26:46.649 (26/01/2024)
#      Found 2346 objects.
#   #  Source finding for '/data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi23pxq_flc.fits', EXT=('SCI', 2) started at: 21:26:47.905 (26/01/2024)
#      Found 2910 objects.
# ===  FINAL number of objects in image '/data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi23pxq_flc.fits': 5256
#
# ===  Source finding for image '/data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi23pzq_flc.fits':
#   #  Source finding for '/data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi23pzq_flc.fits', EXT=('SCI', 1) started at: 21:26:49.425 (26/01/2024)
#      Found 2331 objects.
#   #  Source finding for '/data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi23pzq_flc.fits', EXT=('SCI', 2) started at: 21:26:50.742 (26/01/2024)
#      Found 2491 objects.
# ===  FINAL number of objects in image '/data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi23pzq_flc.fits': 4822
#
#
# ===============================================================
# Performing alignment in the projection plane defined by the WCS
# derived from '/data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi21pgq_flc.fits'
# ===============================================================
#
#
# ====================
# Performing fit for: /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi21phq_flc.fits
#
# Matching sources from '/data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi21phq_flc.fits' with sources from reference image '/data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi21pgq_flc.fits'
# Computing initial guess for X and Y shifts...
# Found initial X and Y shifts of -4.103, -2.453 with significance of 29.22 and 143 matches
# Found 62 matches for /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi21phq_flc.fits...
# Computed  rscale  fit for  /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi21phq_flc.fits :
# XSH: -4.0096  YSH: -1.7645    ROT: 7.260670953e-05    SCALE: 0.999989
# FIT XRMS: 0.042      FIT YRMS: 0.037
# FIT RMSE: 0.056      FIT MAE: 0.028
#
# RMS_RA: 5e-07 (deg)   RMS_DEC: 3.6e-07 (deg)
#
# Final solution based on  50  objects.
# wrote XY data to:  ibzi21phq_flc_catalog_fit.match
# Total # points: 50
# # of points after clipping: 50
# Total # points: 50
# # of points after clipping: 50
#
# ====================
# Performing fit for: /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi21pjq_flc.fits
#
# Matching sources from '/data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi21pjq_flc.fits' with sources from reference image '/data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi21pgq_flc.fits'
# Computing initial guess for X and Y shifts...
# Found initial X and Y shifts of -0.2086, -0.1246 with significance of 23.2 and 145 matches
# Found 54 matches for /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi21pjq_flc.fits...
# Computed  rscale  fit for  /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi21pjq_flc.fits :
# XSH: -0.0951  YSH: -0.0520    ROT: 0.0002366885681    SCALE: 1.000012
# FIT XRMS: 0.34       FIT YRMS: 0.36
# FIT RMSE: 0.5        FIT MAE: 0.38
#
# RMS_RA: 4.1e-06 (deg)   RMS_DEC: 3.6e-06 (deg)
#
# Final solution based on  54  objects.
# wrote XY data to:  ibzi21pjq_flc_catalog_fit.match
# Total # points: 54
# # of points after clipping: 54
# Total # points: 54
# # of points after clipping: 54
#
# ====================
# Performing fit for: /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi21plq_flc.fits
#
# Matching sources from '/data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi21plq_flc.fits' with sources from reference image '/data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi21pgq_flc.fits'
# Computing initial guess for X and Y shifts...
# Found initial X and Y shifts of -0.1989, -0.1989 with significance of 22.33 and 180 matches
# Found 53 matches for /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi21plq_flc.fits...
# Computed  rscale  fit for  /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi21plq_flc.fits :
# XSH: -0.1426  YSH: -0.1792    ROT: 359.9977132    SCALE: 0.999936
# FIT XRMS: 0.33       FIT YRMS: 0.38
# FIT RMSE: 0.5        FIT MAE: 0.39
#
# RMS_RA: 3.9e-06 (deg)   RMS_DEC: 3.8e-06 (deg)
#
# Final solution based on  53  objects.
# wrote XY data to:  ibzi21plq_flc_catalog_fit.match
# Total # points: 53
# # of points after clipping: 53
# Total # points: 53
# # of points after clipping: 53
#
# ====================
# Performing fit for: /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi22pnq_flc.fits
#
# Matching sources from '/data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi22pnq_flc.fits' with sources from reference image '/data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi21pgq_flc.fits'
# Computing initial guess for X and Y shifts...
# Found initial X and Y shifts of 0.8884, 0.8451 with significance of 49.29 and 184 matches
# Found 96 matches for /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi22pnq_flc.fits...
# Computed  rscale  fit for  /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi22pnq_flc.fits :
# XSH: 1.0562  YSH: 0.7517    ROT: 359.9991288    SCALE: 0.999988
# FIT XRMS: 0.12       FIT YRMS: 0.062
# FIT RMSE: 0.14       FIT MAE: 0.12
#
# RMS_RA: 1.4e-06 (deg)   RMS_DEC: 5.6e-07 (deg)
#
# Final solution based on  88  objects.
# wrote XY data to:  ibzi22pnq_flc_catalog_fit.match
# Total # points: 88
# # of points after clipping: 88
# Total # points: 88
# # of points after clipping: 88
#
# ====================
# Performing fit for: /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi22poq_flc.fits
#
# Matching sources from '/data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi22poq_flc.fits' with sources from reference image '/data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi21pgq_flc.fits'
# Computing initial guess for X and Y shifts...
# Found initial X and Y shifts of -3.184, -1.305 with significance of 30.74 and 105 matches
# Found 50 matches for /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi22poq_flc.fits...
# Computed  rscale  fit for  /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi22poq_flc.fits :
# XSH: -3.0701  YSH: -1.1543    ROT: 359.9999179    SCALE: 0.999965
# FIT XRMS: 0.01       FIT YRMS: 0.0083
# FIT RMSE: 0.013      FIT MAE: 0.011
#
# RMS_RA: 1.2e-07 (deg)   RMS_DEC: 8.1e-08 (deg)
#
# Final solution based on  43  objects.
# wrote XY data to:  ibzi22poq_flc_catalog_fit.match
# Total # points: 43
# # of points after clipping: 43
# Total # points: 43
# # of points after clipping: 43
#
# ====================
# Performing fit for: /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi22pqq_flc.fits
#
# Matching sources from '/data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi22pqq_flc.fits' with sources from reference image '/data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi21pgq_flc.fits'
# Computing initial guess for X and Y shifts...
# Found initial X and Y shifts of -2.248, -3.231 with significance of 34.54 and 122 matches
# Found 58 matches for /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi22pqq_flc.fits...
# Computed  rscale  fit for  /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi22pqq_flc.fits :
# XSH: -1.6222  YSH: -3.2336    ROT: 359.9999314    SCALE: 0.999954
# FIT XRMS: 0.0075     FIT YRMS: 0.0067
# FIT RMSE: 0.01       FIT MAE: 0.0086
#
# RMS_RA: 8.8e-08 (deg)   RMS_DEC: 6.6e-08 (deg)
#
# Final solution based on  52  objects.
# wrote XY data to:  ibzi22pqq_flc_catalog_fit.match
# Total # points: 52
# # of points after clipping: 52
# Total # points: 52
# # of points after clipping: 52
#
# ====================
# Performing fit for: /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi22psq_flc.fits
#
# Matching sources from '/data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi22psq_flc.fits' with sources from reference image '/data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi21pgq_flc.fits'
# Computing initial guess for X and Y shifts...
# Found initial X and Y shifts of 1.846, -2.169 with significance of 28.87 and 169 matches
# Found 68 matches for /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi22psq_flc.fits...
# Computed  rscale  fit for  /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi22psq_flc.fits :
# XSH: 2.0543  YSH: -1.8239    ROT: 359.9999738    SCALE: 0.999992
# FIT XRMS: 0.0089     FIT YRMS: 0.013
# FIT RMSE: 0.016      FIT MAE: 0.012
#
# RMS_RA: 1.1e-07 (deg)   RMS_DEC: 1.4e-07 (deg)
#
# Final solution based on  54  objects.
# wrote XY data to:  ibzi22psq_flc_catalog_fit.match
# Total # points: 54
# # of points after clipping: 54
# Total # points: 54
# # of points after clipping: 54
#
# ====================
# Performing fit for: /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi23puq_flc.fits
#
# Matching sources from '/data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi23puq_flc.fits' with sources from reference image '/data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi21pgq_flc.fits'
# Computing initial guess for X and Y shifts...
# Found initial X and Y shifts of -0.09874, -0.2056 with significance of 39.82 and 167 matches
# Found 94 matches for /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi23puq_flc.fits...
# Computed  rscale  fit for  /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi23puq_flc.fits :
# XSH: 0.1551  YSH: 0.0697    ROT: 359.9977421    SCALE: 0.999982
# FIT XRMS: 0.28       FIT YRMS: 0.19
# FIT RMSE: 0.34       FIT MAE: 0.3
#
# RMS_RA: 3.3e-06 (deg)   RMS_DEC: 1.8e-06 (deg)
#
# Final solution based on  92  objects.
# wrote XY data to:  ibzi23puq_flc_catalog_fit.match
# Total # points: 92
# # of points after clipping: 92
# Total # points: 92
# # of points after clipping: 92
#
# ====================
# Performing fit for: /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi23pvq_flc.fits
#
# Matching sources from '/data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi23pvq_flc.fits' with sources from reference image '/data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi21pgq_flc.fits'
# Computing initial guess for X and Y shifts...
# Found initial X and Y shifts of -4.209, -2.318 with significance of 36.39 and 107 matches
# Found 59 matches for /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi23pvq_flc.fits...
# Computed  rscale  fit for  /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi23pvq_flc.fits :
# XSH: -3.9982  YSH: -1.8042    ROT: 359.9999545    SCALE: 0.999954
# FIT XRMS: 0.0081     FIT YRMS: 0.01
# FIT RMSE: 0.013      FIT MAE: 0.011
#
# RMS_RA: 9.9e-08 (deg)   RMS_DEC: 1e-07 (deg)
#
# Final solution based on  50  objects.
# wrote XY data to:  ibzi23pvq_flc_catalog_fit.match
# Total # points: 50
# # of points after clipping: 50
# Total # points: 50
# # of points after clipping: 50
#
# ====================
# Performing fit for: /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi23pxq_flc.fits
#
# Matching sources from '/data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi23pxq_flc.fits' with sources from reference image '/data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi21pgq_flc.fits'
# Computing initial guess for X and Y shifts...
# Found initial X and Y shifts of -2.21, -4.124 with significance of 17.55 and 130 matches
# Found 60 matches for /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi23pxq_flc.fits...
# Computed  rscale  fit for  /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi23pxq_flc.fits :
# XSH: -2.5000  YSH: -4.1817    ROT: 359.9999551    SCALE: 0.999975
# FIT XRMS: 0.0095     FIT YRMS: 0.0092
# FIT RMSE: 0.013      FIT MAE: 0.011
#
# RMS_RA: 1.1e-07 (deg)   RMS_DEC: 9.2e-08 (deg)
#
# Final solution based on  54  objects.
# wrote XY data to:  ibzi23pxq_flc_catalog_fit.match
# Total # points: 54
# # of points after clipping: 54
# Total # points: 54
# # of points after clipping: 54
#
# ====================
# Performing fit for: /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi23pzq_flc.fits
#
# Matching sources from '/data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi23pzq_flc.fits' with sources from reference image '/data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi21pgq_flc.fits'
# Computing initial guess for X and Y shifts...
# Found initial X and Y shifts of 0.6656, -0.009046 with significance of 15.74 and 158 matches
# Found 47 matches for /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi23pzq_flc.fits...
# Computed  rscale  fit for  /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi23pzq_flc.fits :
# XSH: 0.6774  YSH: 0.1608    ROT: 0.0009580094746    SCALE: 0.999972
# FIT XRMS: 0.4        FIT YRMS: 0.38
# FIT RMSE: 0.55       FIT MAE: 0.47
#
# RMS_RA: 4.8e-06 (deg)   RMS_DEC: 3.8e-06 (deg)
#
# Final solution based on  47  objects.
# wrote XY data to:  ibzi23pzq_flc_catalog_fit.match
# Total # points: 47
# # of points after clipping: 47
# Total # points: 47
# # of points after clipping: 47
# Writing out shiftfile : ../lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/shift814_flc.txt
# Trailer file written to:  tweakreg.log
# Short exposures:  []
# Long exposures:  ['../lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi23puq_flc.fits', '../lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi23pvq_flc.fits', '../lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi23pxq_flc.fits', '../lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi23pzq_flc.fits', '../lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi22pnq_flc.fits', '../lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi22poq_flc.fits', '../lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi22pqq_flc.fits', '../lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi22psq_flc.fits', '../lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi21pgq_flc.fits', '../lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi21phq_flc.fits', '../lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi21pjq_flc.fits', '../lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi21plq_flc.fits']
# Setting up logfile :  astrodrizzle.log
# AstroDrizzle Version 3.1.6 (2020-02-19 16:16:30 -0500) started at: 21:27:08.347 (26/01/2024)
#
# ==== Processing Step  Initialization  started at  21:27:08.351 (26/01/2024)
# ******* ERROR *******
# No input file found!  Check specification of parameter "input".
# Quitting...
# ******* ***** *******
# ==== Processing Step Initialization finished at 21:27:08.362 (26/01/2024)
# #################################################################
# #                                                               #
# # No valid images found for processing!                         #
# # Check log file for full details.                              #
# # Exiting AstroDrizzle now...                                   #
# #                                                               #
# #################################################################
# ##############################################################################
# #                                                                            #
# # ERROR:                                                                     #
# # AstroDrizzle Version 3.1.6 encountered a problem!  Processing terminated   #
# # at 21:27:08.372 (26/01/2024).                                              #
# #                                                                            #
# ##############################################################################
#    --------------------          --------------------
#                    Step          Elapsed time
#    --------------------          --------------------
#
#          Initialization          0.0109 sec.
#    ====================          ====================
#                   Total          0.0109 sec.
#
# Trailer file written to:  astrodrizzle.log
# Setting up logfile :  astrodrizzle.log
# AstroDrizzle Version 3.1.6 (2020-02-19 16:16:30 -0500) started at: 21:27:08.449 (26/01/2024)
#
# ==== Processing Step  Initialization  started at  21:27:08.452 (26/01/2024)
#
# ##############################################################################
# #                                                                            #
# # “minmed” is highly recommended for three images,                           #
# #  and is good for four to six images,                                       #
# #  but should be avoided for ten or more images.                             #
# #                                                                            #
# ##############################################################################
# WCS Keywords
#
# Number of WCS axes: 2
# CTYPE : 'RA---TAN'  'DEC--TAN'
# CRVAL : 246.94454047097818  -0.9107264041676274
# CRPIX : 2065.5  2195.5
# CD1_1 CD1_2  : -1.0963675734487113e-05  -9.592042477461851e-07
# CD2_1 CD2_2  : -9.592042477461851e-07  1.0963675734487113e-05
# NAXIS : 4131  4391
# ********************************************************************************
# *
# *  Estimated memory usage:  up to 6520 Mb.
# *  Output image size:       4131 X 4391 pixels.
# *  Output image file:       ~ 207 Mb.
# *  Cores available:         24
# *
# ********************************************************************************
# ==== Processing Step Initialization finished at 21:27:12.133 (26/01/2024)
# ==== Processing Step  Static Mask  started at  21:27:12.135 (26/01/2024)
#
# ==== Processing Step Static Mask finished at 21:27:18.224 (26/01/2024)
# ==== Processing Step  Subtract Sky  started at  21:27:18.228 (26/01/2024)
#
# ***** skymatch started on 2024-01-26 21:27:19.428893
#       Version 1.0.5
#
# 'skymatch' task will apply computed sky differences to input image file(s).
#
# NOTE: Computed sky values WILL NOT be subtracted from image data ('subtractsky'=False).
# 'MDRIZSKY' header keyword will represent sky value *computed* from data.
#
# -----  User specified keywords:  -----
#        Sky Value Keyword:  'MDRIZSKY'
#        Data Units Keyword: 'BUNIT'
#
#
# -----  Input file list:  -----
#
#    **  Input image: 'ibzi23puq_flc.fits'
#        EXT: 'SCI',1;	MASK: ibzi23puq_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: ibzi23puq_skymatch_mask_sci2.fits[0]
#
#    **  Input image: 'ibzi23pvq_flc.fits'
#        EXT: 'SCI',1;	MASK: ibzi23pvq_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: ibzi23pvq_skymatch_mask_sci2.fits[0]
#
#    **  Input image: 'ibzi23pxq_flc.fits'
#        EXT: 'SCI',1;	MASK: ibzi23pxq_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: ibzi23pxq_skymatch_mask_sci2.fits[0]
#
#    **  Input image: 'ibzi23pzq_flc.fits'
#        EXT: 'SCI',1;	MASK: ibzi23pzq_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: ibzi23pzq_skymatch_mask_sci2.fits[0]
#
#    **  Input image: 'ibzi22pnq_flc.fits'
#        EXT: 'SCI',1;	MASK: ibzi22pnq_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: ibzi22pnq_skymatch_mask_sci2.fits[0]
#
#    **  Input image: 'ibzi22poq_flc.fits'
#        EXT: 'SCI',1;	MASK: ibzi22poq_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: ibzi22poq_skymatch_mask_sci2.fits[0]
#
#    **  Input image: 'ibzi22pqq_flc.fits'
#        EXT: 'SCI',1;	MASK: ibzi22pqq_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: ibzi22pqq_skymatch_mask_sci2.fits[0]
#
#    **  Input image: 'ibzi22psq_flc.fits'
#        EXT: 'SCI',1;	MASK: ibzi22psq_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: ibzi22psq_skymatch_mask_sci2.fits[0]
#
#    **  Input image: 'ibzi21pgq_flc.fits'
#        EXT: 'SCI',1;	MASK: ibzi21pgq_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: ibzi21pgq_skymatch_mask_sci2.fits[0]
#
#    **  Input image: 'ibzi21phq_flc.fits'
#        EXT: 'SCI',1;	MASK: ibzi21phq_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: ibzi21phq_skymatch_mask_sci2.fits[0]
#
#    **  Input image: 'ibzi21pjq_flc.fits'
#        EXT: 'SCI',1;	MASK: ibzi21pjq_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: ibzi21pjq_skymatch_mask_sci2.fits[0]
#
#    **  Input image: 'ibzi21plq_flc.fits'
#        EXT: 'SCI',1;	MASK: ibzi21plq_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: ibzi21plq_skymatch_mask_sci2.fits[0]
#
# -----  Sky statistics parameters:  -----
#        statistics function: 'median'
#        lower = None
#        upper = None
#        nclip = 5
#        lsigma = 4.0
#        usigma = 4.0
#        binwidth = 0.1
#
# -----  Data->Brightness conversion parameters for input files:  -----
#
#    *   Image: ibzi23puq_flc.fits
#        EXT = 'SCI',1
#              Data units type: COUNTS
#              EXPTIME: 569.0 [s]
#              Conversion factor (data->brightness):  1.1195893848645824
#        EXT = 'SCI',2
#              Data units type: COUNTS
#              EXPTIME: 569.0 [s]
#              Conversion factor (data->brightness):  1.1195893848645824
#
#    *   Image: ibzi23pvq_flc.fits
#        EXT = 'SCI',1
#              Data units type: COUNTS
#              EXPTIME: 569.0 [s]
#              Conversion factor (data->brightness):  1.1195893848645824
#        EXT = 'SCI',2
#              Data units type: COUNTS
#              EXPTIME: 569.0 [s]
#              Conversion factor (data->brightness):  1.1195893848645824
#
#    *   Image: ibzi23pxq_flc.fits
#        EXT = 'SCI',1
#              Data units type: COUNTS
#              EXPTIME: 569.0 [s]
#              Conversion factor (data->brightness):  1.1195893848645824
#        EXT = 'SCI',2
#              Data units type: COUNTS
#              EXPTIME: 569.0 [s]
#              Conversion factor (data->brightness):  1.1195893848645824
#
#    *   Image: ibzi23pzq_flc.fits
#        EXT = 'SCI',1
#              Data units type: COUNTS
#              EXPTIME: 569.0 [s]
#              Conversion factor (data->brightness):  1.1195893848645824
#        EXT = 'SCI',2
#              Data units type: COUNTS
#              EXPTIME: 569.0 [s]
#              Conversion factor (data->brightness):  1.1195893848645824
#
#    *   Image: ibzi22pnq_flc.fits
#        EXT = 'SCI',1
#              Data units type: COUNTS
#              EXPTIME: 569.0 [s]
#              Conversion factor (data->brightness):  1.1195893848645824
#        EXT = 'SCI',2
#              Data units type: COUNTS
#              EXPTIME: 569.0 [s]
#              Conversion factor (data->brightness):  1.1195893848645824
#
#    *   Image: ibzi22poq_flc.fits
#        EXT = 'SCI',1
#              Data units type: COUNTS
#              EXPTIME: 569.0 [s]
#              Conversion factor (data->brightness):  1.1195893848645824
#        EXT = 'SCI',2
#              Data units type: COUNTS
#              EXPTIME: 569.0 [s]
#              Conversion factor (data->brightness):  1.1195893848645824
#
#    *   Image: ibzi22pqq_flc.fits
#        EXT = 'SCI',1
#              Data units type: COUNTS
#              EXPTIME: 569.0 [s]
#              Conversion factor (data->brightness):  1.1195893848645824
#        EXT = 'SCI',2
#              Data units type: COUNTS
#              EXPTIME: 569.0 [s]
#              Conversion factor (data->brightness):  1.1195893848645824
#
#    *   Image: ibzi22psq_flc.fits
#        EXT = 'SCI',1
#              Data units type: COUNTS
#              EXPTIME: 569.0 [s]
#              Conversion factor (data->brightness):  1.1195893848645824
#        EXT = 'SCI',2
#              Data units type: COUNTS
#              EXPTIME: 569.0 [s]
#              Conversion factor (data->brightness):  1.1195893848645824
#
#    *   Image: ibzi21pgq_flc.fits
#        EXT = 'SCI',1
#              Data units type: COUNTS
#              EXPTIME: 569.0 [s]
#              Conversion factor (data->brightness):  1.1195893848645824
#        EXT = 'SCI',2
#              Data units type: COUNTS
#              EXPTIME: 569.0 [s]
#              Conversion factor (data->brightness):  1.1195893848645824
#
#    *   Image: ibzi21phq_flc.fits
#        EXT = 'SCI',1
#              Data units type: COUNTS
#              EXPTIME: 569.0 [s]
#              Conversion factor (data->brightness):  1.1195893848645824
#        EXT = 'SCI',2
#              Data units type: COUNTS
#              EXPTIME: 569.0 [s]
#              Conversion factor (data->brightness):  1.1195893848645824
#
#    *   Image: ibzi21pjq_flc.fits
#        EXT = 'SCI',1
#              Data units type: COUNTS
#              EXPTIME: 569.0 [s]
#              Conversion factor (data->brightness):  1.1195893848645824
#        EXT = 'SCI',2
#              Data units type: COUNTS
#              EXPTIME: 569.0 [s]
#              Conversion factor (data->brightness):  1.1195893848645824
#
#    *   Image: ibzi21plq_flc.fits
#        EXT = 'SCI',1
#              Data units type: COUNTS
#              EXPTIME: 569.0 [s]
#              Conversion factor (data->brightness):  1.1195893848645824
#        EXT = 'SCI',2
#              Data units type: COUNTS
#              EXPTIME: 569.0 [s]
#              Conversion factor (data->brightness):  1.1195893848645824
#
#
# -----  Computing sky values requested image extensions (detector chips):  -----
#
#    *   Image:   'ibzi23puq_flc.fits['SCI',1,2]'  --  SKY = 4.2556010254900185 (brightness units)
#        Sky change (data units):
#       - EXT = 'SCI',1   delta(MDRIZSKY) = 3.80104   NEW MDRIZSKY = 3.80104
#       - EXT = 'SCI',2   delta(MDRIZSKY) = 3.80104   NEW MDRIZSKY = 3.80104
#    *   Image:   'ibzi23pvq_flc.fits['SCI',1,2]'  --  SKY = 4.636159619572018 (brightness units)
#        Sky change (data units):
#       - EXT = 'SCI',1   delta(MDRIZSKY) = 4.14095   NEW MDRIZSKY = 4.14095
#       - EXT = 'SCI',2   delta(MDRIZSKY) = 4.14095   NEW MDRIZSKY = 4.14095
#    *   Image:   'ibzi23pxq_flc.fits['SCI',1,2]'  --  SKY = 4.381821975742329 (brightness units)
#        Sky change (data units):
#       - EXT = 'SCI',1   delta(MDRIZSKY) = 3.91378   NEW MDRIZSKY = 3.91378
#       - EXT = 'SCI',2   delta(MDRIZSKY) = 3.91378   NEW MDRIZSKY = 3.91378
#    *   Image:   'ibzi23pzq_flc.fits['SCI',1,2]'  --  SKY = 4.179072200433158 (brightness units)
#        Sky change (data units):
#       - EXT = 'SCI',1   delta(MDRIZSKY) = 3.73268   NEW MDRIZSKY = 3.73268
#       - EXT = 'SCI',2   delta(MDRIZSKY) = 3.73268   NEW MDRIZSKY = 3.73268
#    *   Image:   'ibzi22pnq_flc.fits['SCI',1,2]'  --  SKY = 4.162561188975524 (brightness units)
#        Sky change (data units):
#       - EXT = 'SCI',1   delta(MDRIZSKY) = 3.71794   NEW MDRIZSKY = 3.71794
#       - EXT = 'SCI',2   delta(MDRIZSKY) = 3.71794   NEW MDRIZSKY = 3.71794
#    *   Image:   'ibzi22poq_flc.fits['SCI',1,2]'  --  SKY = 4.372403585502718 (brightness units)
#        Sky change (data units):
#       - EXT = 'SCI',1   delta(MDRIZSKY) = 3.90536   NEW MDRIZSKY = 3.90536
#       - EXT = 'SCI',2   delta(MDRIZSKY) = 3.90536   NEW MDRIZSKY = 3.90536
#    *   Image:   'ibzi22pqq_flc.fits['SCI',1,2]'  --  SKY = 4.451887335736783 (brightness units)
#        Sky change (data units):
#       - EXT = 'SCI',1   delta(MDRIZSKY) = 3.97636   NEW MDRIZSKY = 3.97636
#       - EXT = 'SCI',2   delta(MDRIZSKY) = 3.97636   NEW MDRIZSKY = 3.97636
#    *   Image:   'ibzi22psq_flc.fits['SCI',1,2]'  --  SKY = 4.334644606652972 (brightness units)
#        Sky change (data units):
#       - EXT = 'SCI',1   delta(MDRIZSKY) = 3.87164   NEW MDRIZSKY = 3.87164
#       - EXT = 'SCI',2   delta(MDRIZSKY) = 3.87164   NEW MDRIZSKY = 3.87164
#    *   Image:   'ibzi21pgq_flc.fits['SCI',1,2]'  --  SKY = 4.5502745991776505 (brightness units)
#        Sky change (data units):
#       - EXT = 'SCI',1   delta(MDRIZSKY) = 4.06424   NEW MDRIZSKY = 4.06424
#       - EXT = 'SCI',2   delta(MDRIZSKY) = 4.06424   NEW MDRIZSKY = 4.06424
#    *   Image:   'ibzi21phq_flc.fits['SCI',1,2]'  --  SKY = 4.551418665059267 (brightness units)
#        Sky change (data units):
#       - EXT = 'SCI',1   delta(MDRIZSKY) = 4.06526   NEW MDRIZSKY = 4.06526
#       - EXT = 'SCI',2   delta(MDRIZSKY) = 4.06526   NEW MDRIZSKY = 4.06526
#    *   Image:   'ibzi21pjq_flc.fits['SCI',1,2]'  --  SKY = 4.169111940445604 (brightness units)
#        Sky change (data units):
#       - EXT = 'SCI',1   delta(MDRIZSKY) = 3.72379   NEW MDRIZSKY = 3.72379
#       - EXT = 'SCI',2   delta(MDRIZSKY) = 3.72379   NEW MDRIZSKY = 3.72379
#    *   Image:   'ibzi21plq_flc.fits['SCI',1,2]'  --  SKY = 4.435074158488671 (brightness units)
#        Sky change (data units):
#       - EXT = 'SCI',1   delta(MDRIZSKY) = 3.96134   NEW MDRIZSKY = 3.96134
#       - EXT = 'SCI',2   delta(MDRIZSKY) = 3.96134   NEW MDRIZSKY = 3.96134
# ***** skymatch ended on 2024-01-26 21:27:27.562698
# TOTAL RUN TIME: 0:00:08.133805
# ==== Processing Step Subtract Sky finished at 21:27:28.607 (26/01/2024)
# ==== Processing Step  Separate Drizzle  started at  21:27:28.609 (26/01/2024)
#
# WCS Keywords
#
# Number of WCS axes: 2
# CTYPE : 'RA---TAN'  'DEC--TAN'
# CRVAL : 246.94454047097818  -0.9107264041676274
# CRPIX : 2065.5  2195.5
# CD1_1 CD1_2  : -1.0963675734487113e-05  -9.592042477461851e-07
# CD2_1 CD2_2  : -9.592042477461851e-07  1.0963675734487113e-05
# NAXIS : 4131  4391
# -Generating simple FITS output: /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi23pvq_single_sci.fits
# Writing out image to disk: /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi23pvq_single_sci.fits
# -Generating simple FITS output: /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi22psq_single_sci.fits
# -Generating simple FITS output: /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi23pxq_single_sci.fits
# -Generating simple FITS output: /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi22pnq_single_sci.fits
# Writing out image to disk: /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi23pvq_single_wht.fits
# -Generating simple FITS output: /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi23puq_single_sci.fits
# Writing out image to disk: /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi22psq_single_sci.fits
# Writing out image to disk: /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi23pxq_single_sci.fits
# Writing out image to disk: /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi22pnq_single_sci.fits
# -Generating simple FITS output: /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi21pjq_single_sci.fits
# Writing out image to disk: /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi23puq_single_sci.fits
# -Generating simple FITS output: /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi21plq_single_sci.fits
# Writing out image to disk: /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi21pjq_single_sci.fits
# -Generating simple FITS output: /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi22poq_single_sci.fits
# Writing out image to disk: /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi21plq_single_sci.fits
# -Generating simple FITS output: /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi23pzq_single_sci.fits
# -Generating simple FITS output: /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi21pgq_single_sci.fits
# Writing out image to disk: /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi22psq_single_wht.fits
# -Generating simple FITS output: /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi21phq_single_sci.fits
# Writing out image to disk: /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi23pzq_single_sci.fits
# Writing out image to disk: /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi22poq_single_sci.fits
# Writing out image to disk: /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi23pxq_single_wht.fits
# Writing out image to disk: /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi21phq_single_sci.fits
# -Generating simple FITS output: /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi22pqq_single_sci.fits
# Writing out image to disk: /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi21pgq_single_sci.fits
# Writing out image to disk: /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi22pnq_single_wht.fits
# Writing out image to disk: /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi23puq_single_wht.fits
# Writing out image to disk: /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi21pjq_single_wht.fits
# Writing out image to disk: /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi22pqq_single_sci.fits
# Writing out image to disk: /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi21plq_single_wht.fits
# Writing out image to disk: /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F390W_WFC3/reduced_data/temp/ibzi23pzq_single_wht.fits
# ...
# WARNING:               Skipping in-memory file '[<astropy.io.fits.hdu.image.PrimaryHDU object at 0x7f3cccb3f0d0>][0]' [stwcs.wcsutil.altwcs]
# WARNING:               Extension ('WCSDVARR', 1.0) not found. [stwcs.wcsutil.altwcs]
# Writing out image to disk: /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F814W_ACS/reduced_data/temp/j9c701z1q_sci1_blt.fits
#     Blot: creating blotted image:  /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F814W_ACS/reduced_data/temp/j9c701z1q_flc.fits[sci,2]
# Using default C-based coordinate transformation...
# -Generating simple FITS output: /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F814W_ACS/reduced_data/temp/j9c701z1q_sci2_blt.fits
# WARNING: wcs_from_key: Could not read WCS with key A [stwcs.wcsutil.altwcs]
# WARNING:               Skipping in-memory file '[<astropy.io.fits.hdu.image.PrimaryHDU object at 0x7f3ccce64b10>][0]' [stwcs.wcsutil.altwcs]
# WARNING:               Extension ('WCSDVARR', 3.0) not found. [stwcs.wcsutil.altwcs]
# WARNING: wcs_from_key: Could not read WCS with key B [stwcs.wcsutil.altwcs]
# WARNING:               Skipping in-memory file '[<astropy.io.fits.hdu.image.PrimaryHDU object at 0x7f3ccce64b10>][0]' [stwcs.wcsutil.altwcs]
# WARNING:               Extension ('WCSDVARR', 3.0) not found. [stwcs.wcsutil.altwcs]
# Writing out image to disk: /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F814W_ACS/reduced_data/temp/j9c701z1q_sci2_blt.fits
#     Blot: creating blotted image:  /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F814W_ACS/reduced_data/temp/j9c701z3q_flc.fits[sci,1]
# Using default C-based coordinate transformation...
# -Generating simple FITS output: /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F814W_ACS/reduced_data/temp/j9c701z3q_sci1_blt.fits
# WARNING: wcs_from_key: Could not read WCS with key A [stwcs.wcsutil.altwcs]
# WARNING:               Skipping in-memory file '[<astropy.io.fits.hdu.image.PrimaryHDU object at 0x7f3ccce1d090>][0]' [stwcs.wcsutil.altwcs]
# WARNING:               Extension ('WCSDVARR', 1.0) not found. [stwcs.wcsutil.altwcs]
# WARNING: wcs_from_key: Could not read WCS with key B [stwcs.wcsutil.altwcs]
# WARNING:               Skipping in-memory file '[<astropy.io.fits.hdu.image.PrimaryHDU object at 0x7f3ccce1d090>][0]' [stwcs.wcsutil.altwcs]
# WARNING:               Extension ('WCSDVARR', 1.0) not found. [stwcs.wcsutil.altwcs]
# Writing out image to disk: /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F814W_ACS/reduced_data/temp/j9c701z3q_sci1_blt.fits
#     Blot: creating blotted image:  /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F814W_ACS/reduced_data/temp/j9c701z3q_flc.fits[sci,2]
# Using default C-based coordinate transformation...
# -Generating simple FITS output: /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F814W_ACS/reduced_data/temp/j9c701z3q_sci2_blt.fits
# WARNING: wcs_from_key: Could not read WCS with key A [stwcs.wcsutil.altwcs]
# WARNING:               Skipping in-memory file '[<astropy.io.fits.hdu.image.PrimaryHDU object at 0x7f3cccda90d0>][0]' [stwcs.wcsutil.altwcs]
# WARNING:               Extension ('WCSDVARR', 3.0) not found. [stwcs.wcsutil.altwcs]
# WARNING: wcs_from_key: Could not read WCS with key B [stwcs.wcsutil.altwcs]
# WARNING:               Skipping in-memory file '[<astropy.io.fits.hdu.image.PrimaryHDU object at 0x7f3cccda90d0>][0]' [stwcs.wcsutil.altwcs]
# WARNING:               Extension ('WCSDVARR', 3.0) not found. [stwcs.wcsutil.altwcs]
# Writing out image to disk: /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F814W_ACS/reduced_data/temp/j9c701z3q_sci2_blt.fits
#     Blot: creating blotted image:  /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F814W_ACS/reduced_data/temp/j9c701z5q_flc.fits[sci,1]
# Using default C-based coordinate transformation...
# -Generating simple FITS output: /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F814W_ACS/reduced_data/temp/j9c701z5q_sci1_blt.fits
# WARNING: wcs_from_key: Could not read WCS with key A [stwcs.wcsutil.altwcs]
# WARNING:               Skipping in-memory file '[<astropy.io.fits.hdu.image.PrimaryHDU object at 0x7f3ccfa6ac50>][0]' [stwcs.wcsutil.altwcs]
# WARNING:               Extension ('WCSDVARR', 1.0) not found. [stwcs.wcsutil.altwcs]
# WARNING: wcs_from_key: Could not read WCS with key B [stwcs.wcsutil.altwcs]
# WARNING:               Skipping in-memory file '[<astropy.io.fits.hdu.image.PrimaryHDU object at 0x7f3ccfa6ac50>][0]' [stwcs.wcsutil.altwcs]
# WARNING:               Extension ('WCSDVARR', 1.0) not found. [stwcs.wcsutil.altwcs]
# Writing out image to disk: /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F814W_ACS/reduced_data/temp/j9c701z5q_sci1_blt.fits
#     Blot: creating blotted image:  /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F814W_ACS/reduced_data/temp/j9c701z5q_flc.fits[sci,2]
# Using default C-based coordinate transformation...
# -Generating simple FITS output: /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F814W_ACS/reduced_data/temp/j9c701z5q_sci2_blt.fits
# WARNING: wcs_from_key: Could not read WCS with key A [stwcs.wcsutil.altwcs]
# WARNING:               Skipping in-memory file '[<astropy.io.fits.hdu.image.PrimaryHDU object at 0x7f3cccf89610>][0]' [stwcs.wcsutil.altwcs]
# WARNING:               Extension ('WCSDVARR', 3.0) not found. [stwcs.wcsutil.altwcs]
# WARNING: wcs_from_key: Could not read WCS with key B [stwcs.wcsutil.altwcs]
# WARNING:               Skipping in-memory file '[<astropy.io.fits.hdu.image.PrimaryHDU object at 0x7f3cccf89610>][0]' [stwcs.wcsutil.altwcs]
# WARNING:               Extension ('WCSDVARR', 3.0) not found. [stwcs.wcsutil.altwcs]
# Writing out image to disk: /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F814W_ACS/reduced_data/temp/j9c701z5q_sci2_blt.fits
# ==== Processing Step Blot finished at 21:33:03.391 (26/01/2024)
# ==== Processing Step  Driz_CR  started at  21:33:03.393 (26/01/2024)
#
# Creating output: /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F814W_ACS/reduced_data/temp/j9c701ysq_sci1_crmask.fits
# Creating output: /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F814W_ACS/reduced_data/temp/j9c701z1q_sci1_crmask.fits
# Creating output: /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F814W_ACS/reduced_data/temp/j9c701z3q_sci1_crmask.fits
# Creating output: /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F814W_ACS/reduced_data/temp/j9c701z5q_sci1_crmask.fits
# Creating output: /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F814W_ACS/reduced_data/temp/j9c701z1q_sci2_crmask.fits
# Creating output: /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F814W_ACS/reduced_data/temp/j9c701ysq_sci2_crmask.fits
# Creating output: /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F814W_ACS/reduced_data/temp/j9c701z3q_sci2_crmask.fits
# Creating output: /data/des80.b/data/chinyi/dinos/paper_dinosI_for_github/dinos-i/lenses/SDSSJ1627-0053/F814W_ACS/reduced_data/temp/j9c701z5q_sci2_crmask.fits
# ==== Processing Step Driz_CR finished at 21:33:06.225 (26/01/2024)
# ==== Processing Step  Final Drizzle  started at  21:33:06.248 (26/01/2024)
#
# ==== Processing Step Final Drizzle finished at 21:33:06.251 (26/01/2024)
#
# AstroDrizzle Version 3.1.6 is finished processing at 21:33:06.253 (26/01/2024).
#
#
#
#    --------------------          --------------------
#                    Step          Elapsed time
#    --------------------          --------------------
#
#          Initialization          1.1577 sec.
#             Static Mask          2.0245 sec.
#            Subtract Sky          3.4742 sec.
#        Separate Drizzle          2.6222 sec.
#           Create Median          6.5939 sec.
#                    Blot          12.0204 sec.
#                 Driz_CR          2.8326 sec.
#           Final Drizzle          0.0031 sec.
#    ====================          ====================
#                   Total          30.7286 sec.
#
# Trailer file written to:  astrodrizzle.log
# Setting up logfile :  astrodrizzle.log
# AstroDrizzle Version 3.1.6 (2020-02-19 16:16:30 -0500) started at: 21:33:07.781 (26/01/2024)
#
# ==== Processing Step  Initialization  started at  21:33:07.783 (26/01/2024)
#
# WCS Keywords
#
# Number of WCS axes: 2
# CTYPE : 'RA---TAN'  'DEC--TAN'
# CRVAL : 246.95832215577423  -0.8992116591441306
# CRPIX : 2110.0  2121.5
# CD1_1 CD1_2  : -8.932123486035944e-07  -1.386013731058258e-05
# CD2_1 CD2_2  : -1.386013731058258e-05  8.932123486035944e-07
# NAXIS : 4220  4243
# ********************************************************************************
# *
# *  Estimated memory usage:  up to 268 Mb.
# *  Output image size:       4220 X 4243 pixels.
# *  Output image file:       ~ 204 Mb.
# *  Cores available:         1
# *
# ********************************************************************************
# ==== Processing Step Initialization finished at 21:33:10.00 (26/01/2024)
# ==== Processing Step  Static Mask  started at  21:33:10.0 (26/01/2024)
#
# ==== Processing Step Static Mask finished at 21:33:12.059 (26/01/2024)
# ==== Processing Step  Subtract Sky  started at  21:33:12.062 (26/01/2024)
#
# ***** skymatch started on 2024-01-26 21:33:12.548670
#       Version 1.0.5
#
# 'skymatch' task will apply computed sky differences to input image file(s).
#
# NOTE: Computed sky values WILL NOT be subtracted from image data ('subtractsky'=False).
# 'MDRIZSKY' header keyword will represent sky value *computed* from data.
#
# -----  User specified keywords:  -----
#        Sky Value Keyword:  'MDRIZSKY'
#        Data Units Keyword: 'BUNIT'
#
#
# -----  Input file list:  -----
#
#    **  Input image: 'j9c701ysq_flc.fits'
#        EXT: 'SCI',1;	MASK: j9c701ysq_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: j9c701ysq_skymatch_mask_sci2.fits[0]
#
#    **  Input image: 'j9c701z1q_flc.fits'
#        EXT: 'SCI',1;	MASK: j9c701z1q_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: j9c701z1q_skymatch_mask_sci2.fits[0]
#
#    **  Input image: 'j9c701z3q_flc.fits'
#        EXT: 'SCI',1;	MASK: j9c701z3q_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: j9c701z3q_skymatch_mask_sci2.fits[0]
#
#    **  Input image: 'j9c701z5q_flc.fits'
#        EXT: 'SCI',1;	MASK: j9c701z5q_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: j9c701z5q_skymatch_mask_sci2.fits[0]
#
# -----  Sky statistics parameters:  -----
#        statistics function: 'median'
#        lower = None
#        upper = None
#        nclip = 5
#        lsigma = 4.0
#        usigma = 4.0
#        binwidth = 0.1
#
# -----  Data->Brightness conversion parameters for input files:  -----
#
#    *   Image: j9c701ysq_flc.fits
#        EXT = 'SCI',1
#              Data units type: COUNTS
#              EXPTIME: 556.0 [s]
#              Conversion factor (data->brightness):  0.7194244604316545
#        EXT = 'SCI',2
#              Data units type: COUNTS
#              EXPTIME: 556.0 [s]
#              Conversion factor (data->brightness):  0.7194244604316545
#
#    *   Image: j9c701z1q_flc.fits
#        EXT = 'SCI',1
#              Data units type: COUNTS
#              EXPTIME: 556.0 [s]
#              Conversion factor (data->brightness):  0.7194244604316545
#        EXT = 'SCI',2
#              Data units type: COUNTS
#              EXPTIME: 556.0 [s]
#              Conversion factor (data->brightness):  0.7194244604316545
#
#    *   Image: j9c701z3q_flc.fits
#        EXT = 'SCI',1
#              Data units type: COUNTS
#              EXPTIME: 556.0 [s]
#              Conversion factor (data->brightness):  0.7194244604316545
#        EXT = 'SCI',2
#              Data units type: COUNTS
#              EXPTIME: 556.0 [s]
#              Conversion factor (data->brightness):  0.7194244604316545
#
#    *   Image: j9c701z5q_flc.fits
#        EXT = 'SCI',1
#              Data units type: COUNTS
#              EXPTIME: 556.0 [s]
#              Conversion factor (data->brightness):  0.7194244604316545
#        EXT = 'SCI',2
#              Data units type: COUNTS
#              EXPTIME: 556.0 [s]
#              Conversion factor (data->brightness):  0.7194244604316545
#
#
# -----  Computing sky values requested image extensions (detector chips):  -----
#
#    *   Image:   'j9c701ysq_flc.fits['SCI',1,2]'  --  SKY = 35.409941090096666 (brightness units)
#        Sky change (data units):
#       - EXT = 'SCI',1   delta(MDRIZSKY) = 49.2198   NEW MDRIZSKY = 49.2198
#       - EXT = 'SCI',2   delta(MDRIZSKY) = 49.2198   NEW MDRIZSKY = 49.2198
#    *   Image:   'j9c701z1q_flc.fits['SCI',1,2]'  --  SKY = 35.19313455485611 (brightness units)
#        Sky change (data units):
#       - EXT = 'SCI',1   delta(MDRIZSKY) = 48.9185   NEW MDRIZSKY = 48.9185
#       - EXT = 'SCI',2   delta(MDRIZSKY) = 48.9185   NEW MDRIZSKY = 48.9185
#    *   Image:   'j9c701z3q_flc.fits['SCI',1,2]'  --  SKY = 34.86423629650966 (brightness units)
#        Sky change (data units):
#       - EXT = 'SCI',1   delta(MDRIZSKY) = 48.4613   NEW MDRIZSKY = 48.4613
#       - EXT = 'SCI',2   delta(MDRIZSKY) = 48.4613   NEW MDRIZSKY = 48.4613
#    *   Image:   'j9c701z5q_flc.fits['SCI',1,2]'  --  SKY = 35.31749094132896 (brightness units)
#        Sky change (data units):
#       - EXT = 'SCI',1   delta(MDRIZSKY) = 49.0913   NEW MDRIZSKY = 49.0913
#       - EXT = 'SCI',2   delta(MDRIZSKY) = 49.0913   NEW MDRIZSKY = 49.0913
# ***** skymatch ended on 2024-01-26 21:33:15.419410
# TOTAL RUN TIME: 0:00:02.870740
# ==== Processing Step Subtract Sky finished at 21:33:15.722 (26/01/2024)
# ==== Processing Step  Separate Drizzle  started at  21:33:15.723 (26/01/2024)
#
# ==== Processing Step Separate Drizzle finished at 21:33:15.725 (26/01/2024)
# ==== Processing Step  Create Median  started at  21:33:15.726 (26/01/2024)
#
# ==== Processing Step  Blot  started at  21:33:15.728 (26/01/2024)
#
# ==== Processing Step Blot finished at 21:33:15.729 (26/01/2024)
# ==== Processing Step  Driz_CR  started at  21:33:15.730 (26/01/2024)
# ==== Processing Step  Final Drizzle  started at  21:33:15.731 (26/01/2024)
#
# WCS Keywords
#
# Number of WCS axes: 2
# CTYPE : 'RA---TAN'  'DEC--TAN'
# CRVAL : 246.95832215577423  -0.8992116591441306
# CRPIX : 2110.0  2121.5
# CD1_1 CD1_2  : -8.932123486035944e-07  -1.386013731058258e-05
# CD2_1 CD2_2  : -1.386013731058258e-05  8.932123486035944e-07
# NAXIS : 4220  4243
# -Generating simple FITS output: ../lenses/SDSSJ1627-0053/F814W_ACS/reduced_data/SDSSJ1627-0053_F814W_drc_sci.fits
# Writing out image to disk: ../lenses/SDSSJ1627-0053/F814W_ACS/reduced_data/SDSSJ1627-0053_F814W_drc_sci.fits
# Writing out image to disk: ../lenses/SDSSJ1627-0053/F814W_ACS/reduced_data/SDSSJ1627-0053_F814W_drc_wht.fits
# Writing out image to disk: ../lenses/SDSSJ1627-0053/F814W_ACS/reduced_data/SDSSJ1627-0053_F814W_drc_ctx.fits
# ==== Processing Step Final Drizzle finished at 21:33:54.177 (26/01/2024)
#
# AstroDrizzle Version 3.1.6 is finished processing at 21:33:54.18 (26/01/2024).
#
#
#
#    --------------------          --------------------
#                    Step          Elapsed time
#    --------------------          --------------------
#
#          Initialization          2.2194 sec.
#             Static Mask          2.0548 sec.
#            Subtract Sky          3.6598 sec.
#        Separate Drizzle          0.0017 sec.
#           Create Median          0.0000 sec.
#                    Blot          0.0013 sec.
#                 Driz_CR          0.0000 sec.
#           Final Drizzle          38.4461 sec.
#    ====================          ====================
#                   Total          46.3831 sec.
#
# Trailer file written to:  astrodrizzle.log
